# %% [markdown]
# ## Using the em/feat/muinversion branch of SimPEG (http://github.com/simpeg/simpeg)

# %%
from CasingSimulations import * 
# %matplotlib inline

# %%
directory = 'UniformBackground1kmCasing_upto5Hz'
cpfile = "CasingProperties.json"
resultsfile = "MagneticPermeabilityImpacts.hdf5"
rerun = False

# %% [markdown]
# # Model Parameters

# %%
casing_l = 1000.
dsz = -casing_l + 50. 
freqs = [1e-1, 0.5, 1, 2, 5]

# %%
# Save or load Results
cp_file = '{directory}/{cpfile}'.format(directory=directory, cpfile=cpfile)

if rerun is True:   
    cp = CasingProperties(casing_l=casing_l, dsz=dsz)
    cp.freqs = freqs
else:   
    with open(cp_file, 'r') as outfile:   
        cp = CasingProperties.deserialize(json.load(outfile))

# %%
CMesh = CasingMesh(cp)
CMesh.npadx2 = CMesh.npadx2 - 3
CMesh.npadzu = CMesh.npadzu - 3
CMesh.npadzd = CMesh.npadzd - 3
mesh = CMesh.mesh

# %%
print(
    'Cyl Mesh Extent xmax: {},: zmin: {}, zmax: {}'.format(
        mesh.vectorCCx.max(),
        mesh.vectorCCz.min(),
        mesh.vectorCCz.max()
    )
)

print(mesh.nC)
print([500./np.sqrt(cp.sigmaback*f) for f in cp.freqs])
print([500./np.sqrt(cp.sigmacasing*f) for f in cp.freqs])
# Out:
# Cyl Mesh Extent xmax: 208853.54563,: zmin: -183013.550756, zmax: 182014.050756
# 2389520
# [15811.388300841898, 7071.0678118654751, 5000.0, 3535.5339059327375, 2236.0679774997898]
# [0.67419986246324204, 0.30151134457776363, 0.21320071635561044, 0.15075567228888181, 0.095346258924559224]

# %% [markdown]
# # plot model

# %%
fig, ax = plt.subplots(1,1)
mesh.plotGrid(ax=ax)

# fig.savefig('{}/{}'.format(directory, 'CylMesh.png'))

# %%
indActive=mesh.gridCC[:,2] <= 0.
casingMap = Maps.ParametrizedCasingAndLayer(mesh, indActive=indActive, slope=1e8)
actMap_sigma = Maps.InjectActiveCells(mesh, indActive=indActive, valInactive=np.log(cp.sigmaair))
actMap_mu = Maps.InjectActiveCells(mesh, indActive=indActive, valInactive=mu_0)
expMap = Maps.ExpMap(mesh)

sigmaMap = expMap * actMap_sigma * casingMap
muMap = actMap_mu * casingMap

# %%
muModelInd = 1

sigma_m = np.r_[
    np.log(cp.sigmaback), np.log(cp.sigmalayer), np.log(cp.sigmacasing), np.log(cp.sigmainside),
    cp.layer_z.mean(), cp.layer_z[1] - cp.layer_z[0], cp.casing_r, cp.casing_t, 
    cp.casing_z[0], cp.casing_z[1]
]

mu_m = np.r_[
    mu_0, mu_0, cp.muModels[muModelInd]*mu_0, mu_0,
    cp.layer_z.mean(), cp.layer_z[1] - cp.layer_z[0], cp.casing_r, cp.casing_t, 
    cp.casing_z[0], cp.casing_z[1]
]

# %%
# %%time
sigma = sigmaMap * sigma_m
mu = muMap * mu_m
# Out:
# CPU times: user 24.3 s, sys: 909 ms, total: 25.2 s
# Wall time: 26.3 s

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,4))
ax = plotModels(mesh, sigma, mu, xlim=[0.,1.], zlim=[-2200., 100.], ax=ax)
# fig.savefig('{}/{}'.format(directory, 'PhysPropModels'))

# %% [markdown]
# # Set up the Source

# %%
# down-holeSource
dhSrc = DownHoleCasingSrc(mesh, cp.src_a, cp.src_b, cp.casing_a, cp.freqs)
thSrc = TopCasingSource(mesh, np.r_[0.,0.,0], cp.src_b, cp.casing_a, cp.freqs)

# %%
# Plot the source to make sure the path is infact
# connected

fig, ax = plt.subplots(1, 1, figsize=(6, 4))
mesh.plotImage(np.log10(sigma), ax=ax)
mesh.plotGrid(ax=ax)
dhSrc.plotSrc(ax=ax)

ax.set_title('downhole casing source on mesh')

ax.set_xlim([0, 0.2])
ax.set_ylim([-951, -949])

# fig.savefig('{}/{}'.format(directory, 'SourceOnMesh.png'))
# Out:
# (-951, -949)

# %% [markdown]
# # Problem and Survey

# %%
prob = FDEM.Problem3D_h(mesh, sigma=sigma, muMap=muMap)
survey = FDEM.Survey(dhSrc.s_e + thSrc.s_e)
prob.solver = Solver
prob.pair(survey)

# %%
def MuCasingModel(mucasing):
    return np.r_[
        mu_0, mu_0, mucasing*mu_0, mu_0,
        cp.layer_z.mean(), cp.layer_z[1] - cp.layer_z[0], cp.casing_r, cp.casing_t, 
        cp.casing_z[0], cp.casing_z[1]
    ]

# %%
cp.muModels = [1., 50., 100., 200.]
fields = {}

# %%
if rerun is True:
    # create a file to store results
    results = h5py.File("{}/{}".format(directory, resultsfile), "w")
else:
    results = h5py.File("{}/{}".format(directory, resultsfile), "r")

# %%
results.keys()
# Out:
# [u'fields_1', u'fields_100', u'fields_200', u'fields_50']

# %%
# %%time
for muMod in cp.muModels:
    tag = int(muMod)
    curMu = MuCasingModel(muMod)

    if rerun is True:
        print('solving mu = {}mu_0'.format(tag))
        fields[tag] = prob.fields(curMu)
        dbentry = "fields_{tag}".format(tag=tag)
        results.create_dataset(dbentry, data=fields[tag][:,'hSolution'])
        print('... saved fields_{tag}'.format(tag=tag))
        
        # Save parameters used to produce these fields
        with open(cp_file, 'w') as outfile:
            json.dump(cp.serialize(), outfile)

    else:
        print('loading mu = {}mu_0'.format(tag))
        prob.model = curMu
        f = prob.fieldsPair(mesh, survey)
        f[:, 'hSolution'] = results['fields_{}'.format(tag)].value
        fields[tag] = f
        print('... loaded mu = {}mu_0'.format(tag))
# Out:
# loading mu = 1mu_0
# ... loaded mu = 1mu_0
# loading mu = 50mu_0
# ... loaded mu = 50mu_0
# loading mu = 100mu_0
# ... loaded mu = 100mu_0
# loading mu = 200mu_0
# ... loaded mu = 200mu_0
# CPU times: user 1min 40s, sys: 7.74 s, total: 1min 47s
# Wall time: 1min 52s

# %%
def vecplot_j(muind, freqind, reim='real', th_bh = 'bh'):
    fig, ax = plt.subplots(1,1, figsize=(6,8))
    src = survey.getSrcByFreq(survey.freqs[freqind])
    src = src[0] if th_bh == 'bh' else src[1]
    mur = cp.muModels[muind]
    
    print('{} Hz, {} mu_0'.format(cp.freqs[freqind], mur))
    ax1 = plotCurrentDensity(
        mesh, fields[mur][src, 'j'], csx=0.0001, csz=5., 
        xmax=0.15, zmin=10., zmax=-1500., real_or_imag=reim, 
        mirror=True, ax=ax, fig=fig, saveFig=False)
    
    plt.show()
    return ax1

w = widgets.interactive(
        vecplot_j, muind=widgets.IntSlider(min=0, max=len(cp.muModels)-1, continuousUpdate=False),
        freqind=widgets.IntSlider(min=0, max=len(cp.freqs)-1, continuousUpdate=False),
        reim=widgets.ToggleButtons(options=['real', 'imag'], continuousUpdate=False), 
        th_bh=widgets.ToggleButtons(options=['th', 'bh'], continuousUpdate=False)
)
w
#ax.axis('equal', adjustable='box')
# Out:
# 0.1 Hz, 1.0 mu_0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-6251e65a3a69> in <module>()
#      17         th_bh=widgets.ToggleButtons(options=['th', 'bh'], continuousUpdate=False)
#      18 )
# ---> 19 w
#      20 #ax.axis('equal', adjustable='box')
#
# //anaconda/lib/python2.7/site-packages/IPython/core/displayhook.pyc in __call__(self, result)
#     244             self.start_displayhook()
#     245             self.write_output_prompt()
# --> 246             format_dict, md_dict = self.compute_format_data(result)
#     247             self.update_user_ns(result)
#     248             self.fill_exec_result(result)
#
# //anaconda/lib/python2.7/site-packages/IPython/core/displayhook.pyc in compute_format_data(self, result)
#     148
#     149         """
# --> 150         return self.shell.display_formatter.format(result)
#     151
#     152     # This can be set to True by the write_output_prompt method in a subclass
#
# //anaconda/lib/python2.7/site-packages/IPython/core/formatters.pyc in format(self, obj, include, exclude)
#     131         md_dict = {}
#     132
# --> 133         if self.ipython_display_formatter(obj):
#     134             # object handled itself, don't proceed
#     135             return {}, {}
#
# <decorator-gen-11> in __call__(self, obj)
#
# //anaconda/lib/python2.7/site-packages/IPython/core/formatters.pyc in catch_format_error(method, self, *args, **kwargs)
#     188     """show traceback on failed format call"""
#     189     try:
# --> 190         r = method(self, *args, **kwargs)
#     191     except NotImplementedError:
#     192         # don't warn on NotImplementedErrors
#
# //anaconda/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     880             method = get_real_method(obj, self.print_method)
#     881             if method is not None:
# --> 882                 method()
#     883                 return True
#     884
#
# //anaconda/lib/python2.7/site-packages/ipywidgets/widgets/widget.pyc in _ipython_display_(self, **kwargs)
#     481
#     482             self._send({"method": "display"})
# --> 483             self._handle_displayed(**kwargs)
#     484
#     485     def _send(self, msg, buffers=None):
#
# //anaconda/lib/python2.7/site-packages/ipywidgets/widgets/widget.pyc in _handle_displayed(self, **kwargs)
#     447     def _handle_displayed(self, **kwargs):
#     448         """Called when a view has been displayed for this widget instance"""
# --> 449         self._display_callbacks(self, **kwargs)
#     450
#     451     @staticmethod
#
# //anaconda/lib/python2.7/site-packages/ipywidgets/widgets/widget.pyc in __call__(self, *args, **kwargs)
#      60         for callback in self.callbacks:
#      61             try:
# ---> 62                 local_value = callback(*args, **kwargs)
#      63             except Exception as e:
#      64                 ip = get_ipython()
#
# //anaconda/lib/python2.7/site-packages/ipywidgets/widgets/interaction.pyc in <lambda>(_)
#     287             widget.observe(call_f, names='value')
#     288
# --> 289         container.on_displayed(lambda _: call_f(dict(name=None, old=None, new=None)))
#     290
#     291     return container
#
# //anaconda/lib/python2.7/site-packages/ipywidgets/widgets/interaction.pyc in call_f(*args)
#     258             manual_button.disabled = True
#     259         try:
# --> 260             container.result = f(**container.kwargs)
#     261             if container.result is not None:
#     262                 display(container.result)
#
# <ipython-input-21-6251e65a3a69> in vecplot_j(muind, freqind, reim, th_bh)
#       8     ax1 = plotCurrentDensity(
#       9         mesh, fields[mur][src, 'j'], csx=0.0001, csz=5.,
# ---> 10         xmax=0.15, zmin=10., zmax=-1500., real_or_imag=reim, mirror=True, ax=ax, fig=fig, saveFig=False)
#      11     return ax1
#      12
#
# /Users/lindseyjh/git/casingResearch/CasingSimulations.pyc in plotCurrentDensity(mesh, fields_j, saveFig, figsize, fontsize, csx, csz, xmax, zmin, zmax, real_or_imag, mirror, ax, fig, clim)
#     593                 'norm': LogNorm(), 'cmap': plt.get_cmap('viridis')
#     594             },
# --> 595             ax=ax
#     596         )
#     597     plt.colorbar(
#
# /Users/lindseyjh/git/python_symlinks/SimPEG/Mesh/View.pyc in plotSlice(self, v, vType, normal, ind, grid, view, ax, clim, showIt, pcolorOpts, streamOpts, gridOpts)
#     293                         ax=ax, clim=clim, showIt=showIt,
#     294                         pcolorOpts=pcolorOpts, streamOpts=streamOpts,
# --> 295                         gridOpts=gridOpts)
#     296
#     297
#
# /Users/lindseyjh/git/python_symlinks/SimPEG/Mesh/View.pyc in _plotImage2D(self, v, vType, grid, view, ax, clim, showIt, pcolorOpts, streamOpts, gridOpts)
#     369             tMi = self.__class__([np.ones(nxi)*self.hx.sum()/nxi,
#     370                                   np.ones(nyi)*self.hy.sum()/nyi], self.x0)
# --> 371             P = self.getInterpolationMat(tMi.gridCC,'CC',zerosOutside=True)
#     372             Ui = tMi.r(P*mkvc(U), 'CC', 'CC', 'M')
#     373             Vi = tMi.r(P*mkvc(V), 'CC', 'CC', 'M')
#
# /Users/lindseyjh/git/python_symlinks/SimPEG/Mesh/TensorMesh.pyc in getInterpolationMat(self, loc, locType, zerosOutside)
#     316             'CCVz'  -> z-component of vector field defined on cell centers
#     317         """
# --> 318         return self._getInterpolationMat(loc, locType, zerosOutside)
#     319
#     320
#
# /Users/lindseyjh/git/python_symlinks/SimPEG/Mesh/TensorMesh.pyc in _getInterpolationMat(self, loc, locType, zerosOutside)
#     272
#     273         elif locType in ['CC', 'N']:
# --> 274             Q = Utils.interpmat(loc, *self.getTensor(locType))
#     275
#     276         elif locType in ['CCVx', 'CCVy', 'CCVz']:
#
# /Users/lindseyjh/git/python_symlinks/SimPEG/Utils/interputils.pyc in interpmat(locs, x, y, z)
#      57         y = y.astype(float)
#      58         shape = [x.size, y.size]
# ---> 59         inds, vals = _interpmat2D(locs, x, y)
#      60     else:
#      61         y = y.astype(float)
#
# /Users/lindseyjh/git/python_symlinks/SimPEG/Utils/interputils_cython.pyx in SimPEG.Utils.interputils_cython._interpmat2D (SimPEG/Utils/interputils_cython.c:2593)()
#      70     for i in range(npts):
#      71         ind_x1, ind_x2, wx1, wx2 = _interp_point_1D(x, locs[i, 0])
# ---> 72         ind_y1, ind_y2, wy1, wy2 = _interp_point_1D(y, locs[i, 1])
#      73
#      74         inds += [( ind_x1,  ind_y1),
#
# /Users/lindseyjh/git/python_symlinks/SimPEG/Utils/interputils_cython.pyx in SimPEG.Utils.interputils_cython._interp_point_1D (SimPEG/Utils/interputils_cython.c:1407)()
#      15     # TODO: This fails if the point is on the outside of the mesh.
#      16     #       We may want to replace this by extrapolation?
# ---> 17     cdef int im = np.argmin(abs(x-xr_i))
#      18     cdef int ind_x1 = 0
#      19     cdef int ind_x2 = 0
#
# //anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in argmin(a, axis, out)
#     975
#     976
# --> 977 def argmin(a, axis=None, out=None):
#     978     """
#     979     Returns the indices of the minimum values along an axis.
#
# KeyboardInterrupt:

# %%
# %%time 

IxCasing, IzCasing = CasingCurrents(cp, fields, mesh, survey) #sigma_m, indActive, casingMap)
# Out:
# CPU times: user 12.4 s, sys: 8.84 s, total: 21.3 s
# Wall time: 22.9 s

# %%
def plotMe_freq(
    muopt, reim, subtract=None, th=True, bh=True, logScale=True, 
    ylim_0l=-1., ylim_0u=1., ylim_1l=6e-5, ylim_1u=1e-4
):
    ylim_0 = [ylim_0l, ylim_0u]
    ylim_1 = [ylim_1l, ylim_1u]
    
    fig, ax = plt.subplots(2,1, figsize=(10,8))
    mur = cp.muModels[muopt]
    
    srcinds = []
    if bh is True: 
        srcinds += [0]
    if th is True:
        srcinds += [1]
    
    plot_currents_over_freq(
        IxCasing, IzCasing, cp, mesh, mur, subtract=subtract, real_or_imag=reim, 
        ax=ax, logScale=logScale, srcinds=srcinds, ylim_0=ylim_0, ylim_1=ylim_1
    )  
    plt.show()

w = widgets.interact(
    plotMe_freq, 
    muopt=widgets.IntSlider(min=0., max=len(cp.muModels)-1, continuousUpdate=False), 
    reim=widgets.ToggleButtons(options=['real', 'imag'], continuousUpdate=False),
    subtract=widgets.ToggleButtons(options=[None, 1]),
    th=widgets.Checkbox(True),
    bh=widgets.Checkbox(True),
    logScale=widgets.ToggleButtons(options=[True, False], continuousUpdate=False), 
    ylim_0l=widgets.FloatText(1e-3, continuousUpdate=False),
    ylim_0u=widgets.FloatText(1, continuousUpdate=False),
    ylim_1l=widgets.FloatText(6e-5, continuousUpdate=False),
    ylim_1u=widgets.FloatText(1e-4, continuousUpdate=False),
)
# Out:
# mu = 1.0 mu_0

# %%
fig, ax = plt.subplots(2,1, figsize=(10,8))

plot_currents_over_freq(
    IxCasing, IzCasing, cp, mesh, mur=50., real_or_imag='real', 
    ax=ax, logScale=True, srcinds=[1], ylim_0=[1e-2, 1.], ylim_1=[6e-5, 1.5e-4]
) 

ax[0].set_xlabel('z (m)', fontsize=13)
ax[1].set_xlabel('z (m)', fontsize=13)

ax[0].set_ylabel('$I_z$ (A)', fontsize=13)
ax[1].set_ylabel('$I_x$ (A)', fontsize=13)

ax[0].set_title('Vertical Current in Casing')
ax[1].set_title('Horizontal Current in Casing')

plt.tight_layout()

fig.savefig('currents_in_casing.png', dpi=300)
# Out:
# mu = 50.0 mu_0

# %%
def plotMe_mu(
    freqopt, reim, subtract=None, th=True, bh=True, logScale=True, 
    ylim_0l=-1., ylim_0u=1., ylim_1l=6e-5, ylim_1u=1e-4
):
    ylim_0 = [ylim_0l, ylim_0u]
    ylim_1 = [ylim_1l, ylim_1u]
#     fig, ax = plt.subplots(2,1, figsize=(10,8))
    freq = cp.freqs[freqopt]
    srcinds = []
    if bh is True: 
        srcinds += [0]
    if th is True:
        srcinds += [1]
    plot_currents_over_mu(
        IxCasing, IzCasing, cp, mesh, freqopt, subtract=subtract, real_or_imag=reim,
        logScale=logScale, srcinds=srcinds, ylim_0=ylim_0, ylim_1=ylim_1
    )  

w = widgets.interact(
    plotMe_mu, 
    freqopt=widgets.IntSlider(min=0., max=len(cp.freqs)-1, continuousUpdate=False), 
    reim=widgets.ToggleButtons(options=['real', 'imag'], continuousUpdate=False),
    subtract=widgets.ToggleButtons(options=[None, 1], continuousUpdate=False),
    th=widgets.Checkbox(True),
    bh=widgets.Checkbox(True),
    logScale=widgets.ToggleButtons(options=[True, False], continuousUpdate=False),
    ylim_0l=widgets.FloatText(1e-3, continuousUpdate=False),
    ylim_0u=widgets.FloatText(1, continuousUpdate=False),
    ylim_1l=widgets.FloatText(6e-5, continuousUpdate=False),
    ylim_1u=widgets.FloatText(1e-4, continuousUpdate=False)
)

w
# Out:
# 0.1 Hz
# <function __main__.plotMe_mu>

# %%
def plotMe_j_mu_z(
    freqopt, reim, r, subtract=None, th=True, bh=True, logScale=True, 
    ylim_0l=-1., ylim_0u=1., ylim_1l=6e-5, ylim_1u=1e-4
):
    ylim_0 = [ylim_0l, ylim_0u]
    ylim_1 = [ylim_1l, ylim_1u]
    fig, ax = plt.subplots(2,1, figsize=(10,8))
    freq = cp.freqs[freqopt]
    
    srcinds = []
    if bh is True: 
        srcinds += [0]
    if th is True:
        srcinds += [1]
        
    plot_j_over_mu_z(
        cp, fields, mesh, survey, freqopt, subtract=subtract, r=r, srcinds=srcinds,
        real_or_imag=reim, ax=ax, ylim_0 = ylim_0, ylim_1 = ylim_1, logScale=logScale
    )  
#     ax[1].set_ylim([1e-4, 3e-4])

widgets.interact(
    plotMe_j_mu_z, 
    freqopt=widgets.IntSlider(min=0., max=len(cp.freqs)-1, continuousUpdate=False), 
    r=widgets.FloatText(value=1., continuousUpdate=False), 
    reim=widgets.ToggleButtons(options=['real', 'imag']),
    subtract=widgets.ToggleButtons(options=[None, 1]),
    th=widgets.Checkbox(True),
    bh=widgets.Checkbox(True),
    logScale=widgets.ToggleButtons(options=[True, False], continuousUpdate=False),
    ylim_0l=widgets.FloatText(1e-9, continuousUpdate=False),
    ylim_0u=widgets.FloatText(1e-4, continuousUpdate=False),
    ylim_1l=widgets.FloatText(1e-4, continuousUpdate=False),
    ylim_1u=widgets.FloatText(3e-4, continuousUpdate=False)
)
# Out:
# 5.0 Hz

# %%
fig, ax = plt.subplots(2,1, figsize=(10,8))

plot_j_over_mu_z(
    cp, fields, mesh, survey, freqind=4, r=1., srcinds=[0],
    real_or_imag='real', ax=ax, ylim_0=[1e-9, 1e-5], ylim_1=[9e-5, 3e-4], fig=fig,logScale=True
)  

ax[0].set_xlabel('z (m)', fontsize=13)
ax[1].set_xlabel('z (m)', fontsize=13)

ax[0].set_ylabel('$j_z$ (A/m$^2$)', fontsize=13)
ax[1].set_ylabel('$j_x$ (A/m$^2$)', fontsize=13)

ax[0].set_title('Vertical Current Density at r = 1m')
ax[1].set_title('Horizontal Current Density at r = 1m')

plt.tight_layout()

fig.savefig('currents_1m_away.png', dpi=300)
# Out:
# 5.0 Hz

# %%
def plotMe_j_freq_z(
    muind, reim, r, subtract=None, th=True, bh=True, logScale=True, 
    ylim_0l=-1., ylim_0u=1., ylim_1l=6e-5, ylim_1u=1e-4
):
    mur = cp.muModels[muind]
    
    ylim_0 = [ylim_0l, ylim_0u]
    ylim_1 = [ylim_1l, ylim_1u]
    fig, ax = plt.subplots(2,1, figsize=(10,8))
    
    srcinds = []
    if bh is True: 
        srcinds += [0]
    if th is True:
        srcinds += [1]
        
    plot_j_over_freq_z(
        cp, fields, mesh, survey, mur, subtract=subtract, r=r, srcinds=srcinds,
        real_or_imag=reim, ax=ax, ylim_0 = ylim_0, ylim_1 = ylim_1, logScale=logScale
    )  
#     ax[1].set_ylim([1e-4, 3e-4])

widgets.interact(
    plotMe_j_freq_z, 
    muind=widgets.IntSlider(min=0., max=len(cp.freqs)-1, continuousUpdate=False), 
    r=widgets.FloatText(value=1., continuousUpdate=False), 
    reim=widgets.ToggleButtons(options=['real', 'imag']),
    subtract=widgets.ToggleButtons(options=[None, 1]),
    th=widgets.Checkbox(True),
    bh=widgets.Checkbox(True),
    logScale=widgets.ToggleButtons(options=[True, False], continuousUpdate=False),
    ylim_0l=widgets.FloatText(1e-9, continuousUpdate=False),
    ylim_0u=widgets.FloatText(1e-4, continuousUpdate=False),
    ylim_1l=widgets.FloatText(1e-4, continuousUpdate=False),
    ylim_1u=widgets.FloatText(3e-4, continuousUpdate=False)
)
# Out:
# mu = 1.0 mu_0
# <function __main__.plotMe_j_freq_z>

# %%
def plotMe_j_mu_x(
    freqopt, reim, z, subtract=None, th=True, bh=True, logScale=True, 
    ylim_0l=-1., ylim_0u=1., ylim_1l=6e-5, ylim_1u=1e-4
):
    ylim_0 = None #[ylim_0l, ylim_0u]
    ylim_1 = None #[ylim_1l, ylim_1u]
    
    fig, ax = plt.subplots(2,1, figsize=(10,8))
    freq = cp.freqs[freqopt]
    srcinds = []
    if bh is True: 
        srcinds += [0]
    if th is True:
        srcinds += [1]
        
    plot_j_over_mu_x(
        cp, fields, mesh, survey, freqopt, subtract=subtract, z=z, real_or_imag=reim, ax=ax,
        srcinds=srcinds, logScale=logScale, ylim_0=ylim_0, ylim_1=ylim_1
    )
    plt.show()

j_over_x = widgets.interactive(
    plotMe_j_mu_x, 
    freqopt=widgets.IntSlider(min=0., max=len(cp.freqs)-1, continuous_update=False), 
    z=widgets.FloatText(value=-950., continuous_update=False), 
    subtract=widgets.ToggleButtons(options=[None, 1], continuous_update=False), 
    reim=widgets.ToggleButtons(options=['real', 'imag'], continuous_update=False),
    th=widgets.Checkbox(True),
    bh=widgets.Checkbox(True),
    logScale=widgets.ToggleButtons(options=[True, False]),
    ylim_0l=widgets.FloatText(1e-9),
    ylim_0u=widgets.FloatText(1e-4),
    ylim_1l=widgets.FloatText(1e-4),
    ylim_1u=widgets.FloatText(3e-4)
)
j_over_x
# Out:
# mu = 1 mu_0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-6a8b7f613376> in plotMe_j_mu_x(freqopt, reim, z, subtract, th, bh, logScale, ylim_0l, ylim_0u, ylim_1l, ylim_1u)
#      16     plot_j_over_mu_x(
#      17         cp, fields, mesh, survey, freqopt, subtract=subtract, z=z, real_or_imag=reim, ax=ax,
# ---> 18         srcinds=srcinds, logScale=logScale, ylim_0=ylim_0, ylim_1=ylim_1
#      19     )
#      20     plt.show()
#
# /Users/lindseyjh/git/casingResearch/CasingSimulations.pyc in plot_j_over_mu_x(cp, fields, mesh, survey, srcind, mur, z, real_or_imag, subtract, xlim, logScale, srcinds, ylim_0, ylim_1, ax, fig)
#    1066     for i, f in enumerate(cp.freqs):
#    1067         for srcind in srcinds:
# -> 1068             src = survey.getSrcByFreq(survey.freqs[freqind])[srcind]
#    1069             j = Utils.mkvc(fields[mur][src, 'j'].copy())
#    1070
#
# NameError: global name 'freqind' is not defined

# %%
fig, ax = plt.subplots(1,1)
col = ['b', 'g', 'r', 'c', 'm', 'y']

for mur in cp.muModels:
    ax.plot(np.zeros(3), label='{} $\mu_0$'.format(mur))
ax.legend()

fig.savefig('mu_legend', dpi=300)
